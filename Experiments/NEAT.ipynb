# %%
from __future__ import print_function
import os
import neat
import rubiks2
import numpy as np

env = None
difficulty = 14
def eval_genomes(genomes, config):
    global difficulty
    flag_increase = False
    for genome_id, genome in genomes:
        total_done = 0.0
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        for i in range(100):
            state = env.reset(difficulty)
            
            local_done = 0.0
            for i in range(difficulty):
                action = np.argmax(net.activate(state))

                next_state, reward, done, info = env.step(int(action))
                state = next_state
                local_done += done

            total_done += local_done > 0.0
        genome.fitness = total_done/100.0
        if genome.fitness > 0.95:
            flag_increase = True
    if flag_increase:
        difficulty += 1
    print('Difficulty: ', difficulty)
    

def run(config_file):
    # Load configuration.
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)

    # Create the population, which is the top-level object for a NEAT run.
    p = neat.Population(config)

    # Add a stdout reporter to show progress in the terminal.
    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)
    p.add_reporter(neat.Checkpointer(5))

    # Run for up to 300 generations.
    winner = p.run(eval_genomes, 1000)

    # Display the winning genome.
    print('\nBest genome:\n{!s}'.format(winner))

    # Show output of the most fit genome against training data.
    print('\nOutput:')
    winner_net = neat.nn.FeedForwardNetwork.create(winner, config)
    
    for i in range(6):
        env = rubiks2.RubiksEnv2(2, unsolved_reward = -1.0)
        env.step(int(i))
        state = env.get_observation()
        action = np.argmax(winner_net.activate(state))
        env.step(int(action))
        env.render()


if __name__ == '__main__':
    difficulty = 1
    env = rubiks2.RubiksEnv2(2, unsolved_reward = -1.0)
    # Determine path to configuration file. This path manipulation is
    # here so that the script will run successfully regardless of the
    # current working directory.
    local_dir = os.path.dirname('config-feedforward')
    config_path = os.path.join(local_dir, 'config-feedforward')
    run(config_path)
# Out:
#  ****** Running generation 0 ******
#
# Difficulty:  1
# Population's average fitness: 0.16440 stdev: 0.13781
# Best fitness: 0.61000 - size: (6, 432) - species 1 - id 127
# Average adjusted fitness: 0.164
# Mean genetic distance 2.163, standard deviation 0.289
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0   150      0.6    0.164     0
# Total extinctions: 0
# Generation time: 4.266 sec
#
#  ****** Running generation 1 ******
#
# Difficulty:  1
# Population's average fitness: 0.24580 stdev: 0.15179
# Best fitness: 0.72000 - size: (6, 428) - species 1 - id 247
# Average adjusted fitness: 0.246
# Mean genetic distance 2.197, standard deviation 0.265
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1   150      0.7    0.246     0
# Total extinctions: 0
# Generation time: 4.425 sec (4.345 average)
#
#  ****** Running generation 2 ******
#
# Difficulty:  1
# Population's average fitness: 0.30467 stdev: 0.14953
# Best fitness: 0.67000 - size: (6, 431) - species 1 - id 219
# Average adjusted fitness: 0.305
# Mean genetic distance 2.121, standard deviation 0.327
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2   150      0.7    0.305     1
# Total extinctions: 0
# Generation time: 4.302 sec (4.331 average)
#
#  ****** Running generation 3 ******
#
# Difficulty:  1
# Population's average fitness: 0.34187 stdev: 0.17218
# Best fitness: 0.74000 - size: (6, 427) - species 1 - id 471
# Average adjusted fitness: 0.342
# Mean genetic distance 1.995, standard deviation 0.382
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3   150      0.7    0.342     0
# Total extinctions: 0
# Generation time: 4.347 sec (4.335 average)
#
#  ****** Running generation 4 ******
#
# Difficulty:  1
# Population's average fitness: 0.37473 stdev: 0.17068
# Best fitness: 0.89000 - size: (6, 422) - species 1 - id 726
# Average adjusted fitness: 0.375
# Mean genetic distance 2.115, standard deviation 0.317
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4   150      0.9    0.375     0
# Total extinctions: 0
# Generation time: 4.262 sec (4.320 average)
# Saving checkpoint to neat-checkpoint-4
#
#  ****** Running generation 5 ******
#
# Difficulty:  2
# Population's average fitness: 0.41067 stdev: 0.19189
# Best fitness: 1.00000 - size: (6, 425) - species 1 - id 780
# Average adjusted fitness: 0.411
# Mean genetic distance 1.956, standard deviation 0.362
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5   150      1.0    0.411     0
# Total extinctions: 0
# Generation time: 4.344 sec (4.324 average)
#
#  ****** Running generation 6 ******
#
# Difficulty:  2
# Population's average fitness: 0.17273 stdev: 0.10282
# Best fitness: 0.52000 - size: (6, 418) - species 1 - id 953
# Average adjusted fitness: 0.173
# Mean genetic distance 1.758, standard deviation 0.297
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6   150      0.5    0.173     1
# Total extinctions: 0
# Generation time: 7.803 sec (4.821 average)
#
#  ****** Running generation 7 ******
#
# Difficulty:  2
# Population's average fitness: 0.18953 stdev: 0.10394
# Best fitness: 0.48000 - size: (6, 414) - species 1 - id 1042
# Average adjusted fitness: 0.190
# Mean genetic distance 1.824, standard deviation 0.310
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7   150      0.5    0.190     2
# Total extinctions: 0
# Generation time: 7.779 sec (5.191 average)
#
#  ****** Running generation 8 ******
#
# Difficulty:  2
# Population's average fitness: 0.20560 stdev: 0.11111
# Best fitness: 0.55000 - size: (6, 418) - species 1 - id 953
# Average adjusted fitness: 0.206
# Mean genetic distance 1.729, standard deviation 0.309
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8   150      0.6    0.206     3
# Total extinctions: 0
# Generation time: 7.827 sec (5.484 average)
#
#  ****** Running generation 9 ******
#
# Difficulty:  2
# Population's average fitness: 0.23893 stdev: 0.11704
# Best fitness: 0.57000 - size: (6, 414) - species 1 - id 1042
# Average adjusted fitness: 0.239
# Mean genetic distance 1.724, standard deviation 0.243
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9   150      0.6    0.239     4
# Total extinctions: 0
# Generation time: 8.723 sec (5.808 average)
# Saving checkpoint to neat-checkpoint-9
#
#  ****** Running generation 10 ******
#
# Difficulty:  2
# Population's average fitness: 0.20987 stdev: 0.10662
# Best fitness: 0.52000 - size: (7, 415) - species 1 - id 1337
# Average adjusted fitness: 0.210
# Mean genetic distance 1.760, standard deviation 0.260
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10   150      0.5    0.210     5
# Total extinctions: 0
# Generation time: 8.916 sec (6.273 average)
#
#  ****** Running generation 11 ******
#
# Difficulty:  2
# Population's average fitness: 0.19640 stdev: 0.10893
# Best fitness: 0.54000 - size: (7, 415) - species 1 - id 1337
# Average adjusted fitness: 0.196
# Mean genetic distance 1.710, standard deviation 0.285
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11   150      0.5    0.196     6
# Total extinctions: 0
# Generation time: 8.284 sec (6.659 average)
#
#  ****** Running generation 12 ******
#
# Difficulty:  2
# Population's average fitness: 0.21087 stdev: 0.11132
# Best fitness: 0.57000 - size: (6, 416) - species 1 - id 1824
# Average adjusted fitness: 0.211
# Mean genetic distance 1.659, standard deviation 0.325
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12   150      0.6    0.211     7
# Total extinctions: 0
# Generation time: 8.429 sec (7.071 average)
#
#  ****** Running generation 13 ******
#
# Difficulty:  2
# Population's average fitness: 0.22513 stdev: 0.10952
# Best fitness: 0.53000 - size: (6, 416) - species 1 - id 1824
# Average adjusted fitness: 0.225
# Mean genetic distance 1.808, standard deviation 0.277
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13   150      0.5    0.225     8
# Total extinctions: 0
# Generation time: 9.114 sec (7.548 average)
#
#  ****** Running generation 14 ******
#
# Difficulty:  2
# Population's average fitness: 0.23313 stdev: 0.12798
# Best fitness: 0.62000 - size: (6, 401) - species 1 - id 2094
# Average adjusted fitness: 0.203
# Mean genetic distance 1.762, standard deviation 0.266
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14   150      0.6    0.203     9
# Total extinctions: 0
# Generation time: 9.183 sec (8.040 average)
# Saving checkpoint to neat-checkpoint-14
#
#  ****** Running generation 15 ******
#
# Difficulty:  2
# Population's average fitness: 0.24920 stdev: 0.13566
# Best fitness: 0.63000 - size: (6, 402) - species 1 - id 2334
# Average adjusted fitness: 0.249
# Mean genetic distance 1.683, standard deviation 0.285
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15   150      0.6    0.249    10
# Total extinctions: 0
# Generation time: 8.799 sec (8.486 average)
#
#  ****** Running generation 16 ******
#
# Difficulty:  2
# Population's average fitness: 0.26620 stdev: 0.11275
# Best fitness: 0.68000 - size: (6, 401) - species 1 - id 2405
# Average adjusted fitness: 0.216
# Mean genetic distance 1.761, standard deviation 0.287
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16   150      0.7    0.216    11
# Total extinctions: 0
# Generation time: 8.483 sec (8.554 average)
#
#  ****** Running generation 17 ******
# Difficulty:  2
# Population's average fitness: 0.27207 stdev: 0.12909
# Best fitness: 0.76000 - size: (6, 401) - species 1 - id 2405
# Average adjusted fitness: 0.272
# Mean genetic distance 1.891, standard deviation 0.302
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17   150      0.8    0.272    12
# Total extinctions: 0
# Generation time: 8.486 sec (8.624 average)
#
#  ****** Running generation 18 ******
#
# Difficulty:  2
# Population's average fitness: 0.28253 stdev: 0.14339
# Best fitness: 0.73000 - size: (6, 401) - species 1 - id 2405
# Average adjusted fitness: 0.283
# Mean genetic distance 1.896, standard deviation 0.239
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18   150      0.7    0.283    13
# Total extinctions: 0
# Generation time: 8.607 sec (8.702 average)
#
#  ****** Running generation 19 ******
#
# Difficulty:  2
# Population's average fitness: 0.28460 stdev: 0.12609
# Best fitness: 0.71000 - size: (6, 401) - species 1 - id 2405
# Average adjusted fitness: 0.285
# Mean genetic distance 1.853, standard deviation 0.211
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19   150      0.7    0.285    14
# Total extinctions: 0
# Generation time: 8.709 sec (8.701 average)
# Saving checkpoint to neat-checkpoint-19
#
#  ****** Running generation 20 ******
#
# Difficulty:  2
# Population's average fitness: 0.26860 stdev: 0.12784
# Best fitness: 0.75000 - size: (6, 401) - species 1 - id 2405
# Average adjusted fitness: 0.239
# Mean genetic distance 1.916, standard deviation 0.213
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20   150      0.8    0.239    15
# Total extinctions: 0
# Generation time: 8.804 sec (8.690 average)
#
#  ****** Running generation 21 ******
#
# Difficulty:  2
# Population's average fitness: 0.29100 stdev: 0.14207
# Best fitness: 0.67000 - size: (6, 401) - species 1 - id 2405
# Average adjusted fitness: 0.291
# Mean genetic distance 1.829, standard deviation 0.281
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21   150      0.7    0.291    16
# Total extinctions: 0
# Generation time: 8.647 sec (8.726 average)
#
#  ****** Running generation 22 ******
#
# Difficulty:  2
# Population's average fitness: 0.29673 stdev: 0.13527
# Best fitness: 0.81000 - size: (6, 401) - species 1 - id 2405
# Average adjusted fitness: 0.267
# Mean genetic distance 1.672, standard deviation 0.289
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22   150      0.8    0.267    17
# Total extinctions: 0
# Generation time: 8.931 sec (8.776 average)
#
#  ****** Running generation 23 ******
#
# Difficulty:  2
# Population's average fitness: 0.29260 stdev: 0.13434
# Best fitness: 0.75000 - size: (6, 401) - species 1 - id 2405
# Average adjusted fitness: 0.293
# Mean genetic distance 1.697, standard deviation 0.329
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23   150      0.8    0.293    18
# Total extinctions: 0
# Generation time: 8.550 sec (8.720 average)
#
#  ****** Running generation 24 ******
#
# Difficulty:  2
# Population's average fitness: 0.31073 stdev: 0.14002
# Best fitness: 0.70000 - size: (6, 393) - species 1 - id 3592
# Average adjusted fitness: 0.271
# Mean genetic distance 1.763, standard deviation 0.296
# Population of 150 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24   150      0.7    0.271    19
# Total extinctions: 0
# Generation time: 8.532 sec (8.655 average)
# Saving checkpoint to neat-checkpoint-24
#
#  ****** Running generation 25 ******
#
# Difficulty:  2
# Population's average fitness: 0.31107 stdev: 0.13229
# Best fitness: 0.72000 - size: (6, 393) - species 1 - id 3592
#
# Species 1 with 150 members is stagnated: removing it
# All species extinct.
# ---------------------------------------------------------------------------
# CompleteExtinctionException               Traceback (most recent call last)
# <ipython-input-11-ec4e23b0fbbc> in <module>()
#      75     local_dir = os.path.dirname('config-feedforward')
#      76     config_path = os.path.join(local_dir, 'config-feedforward')
# ---> 77     run(config_path)
#
# <ipython-input-11-ec4e23b0fbbc> in run(config_file)
#      49
#      50     # Run for up to 300 generations.
# ---> 51     winner = p.run(eval_genomes, 1000)
#      52
#      53     # Display the winning genome.
#
# ~/anaconda3/lib/python3.6/site-packages/neat/population.py in run(self, fitness_function, n)
#     122                                                                    self.config.pop_size)
#     123                 else:
# --> 124                     raise CompleteExtinctionException()
#     125
#     126             # Divide the new population into species.
#
# CompleteExtinctionException:
